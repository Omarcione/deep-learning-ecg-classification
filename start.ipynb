# %%
import numpy as numpy
import sklearn
import torch
import os

# %%
if not os.path.exists('ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3.zip'):
    # !wget -r -N -c -np https://physionet.org/files/ptb-xl/1.0.3/
    # !unzip ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3.zip

# %%
# !wget -r -N -c -np https://physionet.org/files/ptb-xl/1.0.3/
# Out:
# --2026-03-06 12:26:34--  https://physionet.org/files/ptb-xl/1.0.3/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/index.html’
#
# physionet.org/files     [ <=>                ]   1.39K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-03-06 12:26:34 (598 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/index.html’ saved [1427]
#
# Loading robots.txt; please ignore errors.
# --2026-03-06 12:26:34--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# ...
